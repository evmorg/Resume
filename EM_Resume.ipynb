# %% [markdown]
# <a href="https://colab.research.google.com/github/evmorg/Resume/blob/main/EM_Resume.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries and files
import matplotlib.pyplot as plt
from google.colab import files

# %%
# Text Variables
Name = 'Evan Morgan'
Title = 'Data Analytics & Database Management'
ContactHeader = 'CONTACT'
Contact = 'Denver, CO\n216-262-2605\nevanmorgan@duck.com\nlinkedin.com/in/evmorgan\ngithub.com/evmorg'

EduHeader = 'EDUCATION'
EduOneTitle = 'The Ohio State University, M.S. in Biomedical Informatics'
# EduOneTime = ''
EduOneDesc = '- Thesis published by Digital Health of Sage Journals: "Outpatient portal use among pregnant individuals: Cross-sectional, temporal, and cluster analysis of use"'
EduTwoTitle = 'College of the Holy Cross, B.A. in Psychology'
# EduTwoTime = ''

WorkHeader = 'EXPERIENCE'
WorkOneTitle = 'Ohio State University Medical Center - Data Management Analyst'
WorkOneTime = 'Jan 2020-Present'
WorkOneDesc = '- Build and maintain databases using Microsoft (MS) SQL Server and Access\n  for the Cellular Therapy and Blood and Marrow Transplant (BMT) Program\n- Create tables, queries and reports within MS Access needed for research,\n  quality management and reporting to international agencies\n- Oversaw external audit of data required for FACT accreditation\n- Partnered with data warehousing team to migrate local MS Access databases\n  to MS SQL Server\n- Identified, projected, and reported a new annual revenue stream (~$65,000)\n  to administrative leaders within the Cellular Therapy & BMT Program'
WorkTwoTitle = 'Ohio State University Medical Center - Sr. Clinical Research Coordinator'
WorkTwoTime = 'Nov 2017-Jan 2020'
WorkTwoDesc = '- Built and maintained REDCap and local MS Access databases for the\n  Division of Medical Oncology\n- Ensured regulatory compliance and coordinated data collection for 20+\n  research protocols\n- Facilitated publication of 15 studies, including one first author publication '
WorkThreeTitle = 'Dana-Farber Cancer Institute - Clinical Research Coordinator'
WorkThreeTime = 'Aug 2013-Nov 2017'
WorkThreeDesc = '- Maintained regulatory compliance, coordinated data collection and interacted\n  with patients for a prospective multi-center study (1,300+ patients) for the\n  Breast Oncology Program\n- Participated in design and build of locally stored MS Access databases\n- Wrote and designed study protocols alongside physicians and statisticians'

ProjectsHeader = 'PROJECTS & PUBLICATIONS'
ProjectOneTitle = 'Published Log File Analysis and Visualization'
ProjectOneDesc = '- M.S. Thesis published by Digital Health of Sage Journals\n- Processed Epic MyChart log files to characterize and identify clusters of\n  users via hierarchical cluster analysis\n- Defined a data model, and cleaned and visualized data\n- Results can be used to improve MyChart provider training and user experience'
ProjectTwoTitle = 'Microsoft (MS) SQL Server Database for Cellular Therapy Program'
ProjectTwoDesc = '- Independently designed, built and maintained a MS SQL Server database\n  and the MS Access front-end user interface\n- Developed ad-hoc and canned tools (queries, reports and dashboards) to meet\n  needs of Cellular Therapy Program stakeholders\n- The increased efficiency of data collection and reporting to international\n  agencies resulted in a new program revenue stream that funded a new hire'
ProjectThreeTitle = 'Python Web Scraping, Data Cleaning and Data Visualization'
ProjectThreeDesc = "- Iteratively scraped HTML from Spotrac.com to create accessible NFL\n  contract data frames\n- Cleaned and transformed NFL contract and production data for analysis\n- Visualized NFL team annual production and NFL player's annual\n  production relative to total team salary and player's salaries"

SkillsHeader = 'SKILLS'
SkillsDesc = '- Python (pandas, NumPy, urllib,\n  Beautiful Soup, Matplotlib,\n  Plotly, seaborn)\n- T-SQL\n- Visual Basic\n- R (dplyr, tidyverse, ggplot2)\n- Stata\n- Git and Version Control\n- Command Line/Bash\n- MS SQL Server (SSMS, SSIS,\n  SSRS, SSAS)\n- MS Access\n- Tableau\n- Data Visualization\n- Data Cleaning\n- Probability/Statistics'
CertifsTitle = 'CERTIFICATIONS'
CertifsDesc = '- MS Azure Data Engineering\n  Associate (in prog.)\n- Google Data Analytics\n- Udemy Data Warehouse\n  Developer\n- Udemy SQL Bootcamp'
ExtrasTitle = 'ABOUT ME'
ExtrasDesc = '- Skilled in health informatics,\n  healthcare analytics, data\n  analysis and database\n  management\n- A detail-oriented and resourceful\n  troubleshooter\n- A personable and patient\n  teammate\n- An avid hiker, cyclist and\n  ultimate frisbee player'
CitationsTitle = 'CITATIONS'
CitationsDesc = 'tinyurl.com/gscholarEvMrg'
Footer = 'This resume was generated entirely in Python. For full sourcecode, view project on github.'

# %%
# Setting style for bar graphs
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'
fig, ax = plt.subplots(figsize=(8.5, 11))

# Decorative Lines
# ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='gray', linewidth=285)
# plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text
plt.annotate(Name, (.01,.96), weight='bold', fontsize=20)

plt.annotate(Title, (.01,.93), weight='regular', fontsize=14)

plt.annotate(EduHeader, (.01,.9), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle, (.01,.88), weight='regular', fontsize=10)
# plt.annotate(EduOneTime, (.01,.14), weight='regular', fontsize=9, alpha=.6)
# plt.annotate(EduOneDesc, (.03,.125), weight='regular', fontsize=9)
plt.annotate(EduTwoTitle, (.01,.86), weight='regular', fontsize=10)
# plt.annotate(EduTwoTime, (.01,.065), weight='regular', fontsize=9, alpha=.6)

plt.annotate(WorkHeader, (.01,.83), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(WorkOneTitle, (.01,.81), weight='bold', fontsize=10)
plt.annotate(WorkOneTime, (.01,.794), weight='regular', fontsize=9.5, alpha=.6)
plt.annotate(WorkOneDesc, (.03,.643), weight='regular', fontsize=9.5)
plt.annotate(WorkTwoTitle, (.01,.62), weight='bold', fontsize=10)
plt.annotate(WorkTwoTime, (.01,.604), weight='regular', fontsize=9.5, alpha=.6)
plt.annotate(WorkTwoDesc, (.03,.52), weight='regular', fontsize=9.5)
plt.annotate(WorkThreeTitle, (.01,.5), weight='bold', fontsize=10)
plt.annotate(WorkThreeTime, (.01,.484), weight='regular', fontsize=9.5, alpha=.6)
plt.annotate(WorkThreeDesc, (.03,.4), weight='regular', fontsize=9.5)

plt.annotate(ProjectsHeader, (.01,.37), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(ProjectOneTitle, (.01,.35), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.03,.2675), weight='regular', fontsize=9.5)
plt.annotate(ProjectTwoTitle, (.01,.25), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.03,.1500), weight='regular', fontsize=9.5)
plt.annotate(ProjectThreeTitle, (.01,.1325), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.03,.0475), weight='regular', fontsize=9.5)

plt.annotate(ContactHeader, (.7,.97), weight='bold', fontsize=10, color='white')
plt.annotate(Contact, (.71,.88), weight='regular', fontsize=10, color='white')
plt.annotate(SkillsHeader, (.7,.82), weight='bold', fontsize=10, color='white')
plt.annotate(SkillsDesc, (.7,.54), weight='regular', fontsize=10, color='white')
plt.annotate(CertifsTitle, (.7,.47), weight='bold', fontsize=10, color='white')
plt.annotate(CertifsDesc, (.7,.36), weight='regular', fontsize=10, color='white')
plt.annotate(ExtrasTitle, (.7,.3), weight='bold', fontsize=10, color='white')
plt.annotate(ExtrasDesc, (.7,.1225), weight='regular', fontsize=10, color='white')
plt.annotate(CitationsTitle, (.7,.06), weight='bold', fontsize=10, color='white')
plt.annotate(CitationsDesc, (.71,.04), weight='regular', fontsize=10, color='white')

plt.annotate(Footer, (.01,.01), weight='regular', fontsize=8, alpha=.75)

plt.savefig('EM_res.pdf', dpi=300, bbox_inches='tight')

# %%
# !pip install PyPDF2
from PyPDF2 import PdfReader, PdfWriter
from PyPDF2.generic import RectangleObject as ro

reader = PdfReader('EM_res.pdf')
writer = PdfWriter()

for page in reader.pages:
    writer.add_page(page)

# Make a black rectangle in the bottom-left corner with the link
writer.add_uri(
    page_number=0,
    uri="https://github.com/evmorg",
    rect=ro([280, 10, 302, 20]),
    border = 'dott'
)
output = open('EM_resume.pdf','wb')
writer.write(output)
output.close()
# files.download('EM_resume.pdf')
# Out:
# WARNING:PyPDF2.generic._base:Incorrect first char in NameObject:(d)
# WARNING:PyPDF2.generic._base:Incorrect first char in NameObject:(o)
# WARNING:PyPDF2.generic._base:Incorrect first char in NameObject:(t)
# WARNING:PyPDF2.generic._base:Incorrect first char in NameObject:(t)

# %% [markdown]
# source:
# https://towardsdatascience.com/generating-a-resume-in-python-1480a4d6a399
