# %% [markdown]
# <a href="https://colab.research.google.com/github/evmorg/Resume/blob/main/EM_Resume.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries and files
import matplotlib.pyplot as plt
from google.colab import files

# %%
# Text Variables
Name = 'Evan Morgan'
Title = 'Data Analytics & Database Management'
ContactHeader = 'CONTACT'
Contact = 'Denver, CO\n216-262-2605\nevanmorgan@duck.com\nlinkedin.com/in/evmorgan\ngithub.com/evmorg'
EduHeader = 'EDUCATION'
EduOneTitle = 'The Ohio State University, M.S. in Biomedical Informatics'
# EduOneTime = ''
EduOneDesc = '- Thesis published by Digital Health, Sage Journals: "Outpatient portal use among pregnant individuals: Cross-sectional, temporal, and cluster analysis of use"'
EduTwoTitle = 'College of the Holy Cross, B.A.'
# EduTwoTime = ''
ProjectsHeader = 'PROJECTS & PUBLICATIONS'
ProjectOneTitle = 'Published Log File Analysis and Visualization'
ProjectOneDesc = '- MS Thesis published by Digital Health, Sage Journals\n- Analyzed Epic MyChart log files to identify clusters of users\n- Cleaned and visualized data using Stata, R, and Python\n- Results can be used to improve MyChart provider training and user experience'
ProjectTwoTitle = 'SQL Server Database Build for Data Reporting and Analysis'
ProjectTwoDesc = '- Independently designed, built and maintained database using T-SQL, SSMS,\n  Visual Basic, and MS Access\n- Developed ad-hoc and recurring queries and reports to meet needs of BMT &\n  Cellular Therapy Program stakeholders'
ProjectThreeTitle = 'Python Web Scraping, Data Cleaning and Data Visualization'
ProjectThreeDesc = "- Iteratively scraped HTML from Spotrac.com using Python to create accessible\n  NFL contract dataframes\n- Cleaned and transformed NFL contract and production data for analysis using\n  Pandas and NumPy libraries in Python\n- Used Matplotlib and Seaborn libraries to visualize NFL player's annual\n  production relative to salary"
WorkHeader = 'EXPERIENCE'
WorkOneTitle = 'Ohio State University Medical Center / Data Management Analyst'
WorkOneTime = 'Jan 2020-Present'
WorkOneDesc = '- Build and maintain databases using Microsoft SQL Server (T-SQL, SSMS),\n  Visual Basic and Microsoft Access for the BMT & Cellular Therapy Program\n- Build tables, queries, reports within Microsoft Access needed for research,\n  quality management, and reporting to international agencies\n- Led team through external audit of cellular therapy data required for BMT &\n  Cellular Therapy Program accreditation\n- Trained team members in use of T-SQL, SSMS, and Visual Basic\n- Led initiative to migrate locally stored MS Access databases to SQL Server'
WorkTwoTitle = 'Ohio State University Medical Center / Sr. Clinical Research Coordinator'
WorkTwoTime = 'Aug 2017-Jan 2020'
WorkTwoDesc = '- Built and maintained locally stored Microsoft Access and Redcap databases\n- Performed medical record review and data collection to aid in analysis and\n  publication\n- Ensured study compliance with all CSRC and IRB requirements regarding\n  observational, interventional, translational research protocols'
WorkThreeTitle = 'Dana-Farber Cancer Institute / Clinical Research Coordinator'
WorkThreeTime = 'Aug 2013-Aug 2017'
WorkThreeDesc = '- Wrote and aided in design of study protocols\n- Ensured study compliance with all IRB requirements\n- Obtained patient consent, survey responses, medical records and tumor\n  tissue samples to ensure study progress\n- Aided in design and build of locally stored MS Access databases'
SkillsHeader = 'SKILLS'
SkillsDesc = '- Python\n- T-SQL\n- R\n- Visual Basic\n- Stata\n- Git and Version Control\n- Command Line\n- MS SQL Server (SSMS, SSIS,\n  SSRS, SSAS)\n- Tableau\n- MS Access\n- MS Excel\n- Data Visualization\n- Data Cleaning\n- Data Manipulation\n- Probability/Statistics'
CertifsTitle = 'CERTIFICATIONS'
CertifsDesc = '- MS Azure Data Engineering\n  Associate (in prog.)\n- Google Data Analytics\n- Udemy Data Warehouse\n  Developer\n- Udemy SQL Bootcamp'
ExtrasTitle = 'ABOUT ME'
ExtrasDesc = '- Ten years of experience in data\n  analysis and database\n  management\n- Searching for job opportunities\n  in data analytics and data\n  engineering\n- Love to hike, cycle, and\n  play ultimate\n- Please see my github for\n  recently completed projects'
CitationsTitle = 'CITATIONS'
CitationsDesc = 'tinyurl.com/gscholarEvMrg'
Footer = 'This resume was generated entirely in Python. For full sourcecode, view my github.'

# %%
# Setting style for bar graphs
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'
fig, ax = plt.subplots(figsize=(8.5, 11))

# Decorative Lines
# ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='gray', linewidth=285)
# plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text
plt.annotate(Name, (.01,.96), weight='bold', fontsize=20)

plt.annotate(Title, (.01,.93), weight='regular', fontsize=14)

plt.annotate(EduHeader, (.01,.9), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle, (.01,.88), weight='regular', fontsize=10)
# plt.annotate(EduOneTime, (.01,.14), weight='regular', fontsize=9, alpha=.6)
# plt.annotate(EduOneDesc, (.03,.125), weight='regular', fontsize=9)

plt.annotate(EduTwoTitle, (.01,.86), weight='regular', fontsize=10)
# plt.annotate(EduTwoTime, (.01,.065), weight='regular', fontsize=9, alpha=.6)

plt.annotate(ProjectsHeader, (.01,.83), weight='bold', fontsize=10, color='#58C1B2')

plt.annotate(ProjectOneTitle, (.01,.81), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.03,.74), weight='regular', fontsize=9.5)

plt.annotate(ProjectTwoTitle, (.01,.72), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.03,.65), weight='regular', fontsize=9.5)

plt.annotate(ProjectThreeTitle, (.01,.63), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.03,.525), weight='regular', fontsize=9.5)

plt.annotate(WorkHeader, (.01,.5), weight='bold', fontsize=10, color='#58C1B2')\

plt.annotate(WorkOneTitle, (.01,.48), weight='bold', fontsize=10)
plt.annotate(WorkOneTime, (.01,.46), weight='regular', fontsize=9.5, alpha=.6)
plt.annotate(WorkOneDesc, (.03,.3225), weight='regular', fontsize=9.5)

plt.annotate(WorkTwoTitle, (.01,.3), weight='bold', fontsize=10)
plt.annotate(WorkTwoTime, (.01,.28), weight='regular', fontsize=9.5, alpha=.6)
plt.annotate(WorkTwoDesc, (.03,.1925), weight='regular', fontsize=9.5)

plt.annotate(WorkThreeTitle, (.01,.17), weight='bold', fontsize=10)
plt.annotate(WorkThreeTime, (.01,.15), weight='regular', fontsize=9.5, alpha=.6)
plt.annotate(WorkThreeDesc, (.03,.0625), weight='regular', fontsize=9.5)

plt.annotate(ContactHeader, (.7,.97), weight='bold', fontsize=10, color='white')
plt.annotate(Contact, (.71,.88), weight='regular', fontsize=10, color='white')

plt.annotate(SkillsHeader, (.7,.82), weight='bold', fontsize=10, color='white')
plt.annotate(SkillsDesc, (.7,.54), weight='regular', fontsize=10, color='white')

plt.annotate(CertifsTitle, (.7,.47), weight='bold', fontsize=10, color='white')
plt.annotate(CertifsDesc, (.7,.36), weight='regular', fontsize=10, color='white')

plt.annotate(ExtrasTitle, (.7,.3), weight='bold', fontsize=10, color='white')
plt.annotate(ExtrasDesc, (.7,.12), weight='regular', fontsize=10, color='white')

plt.annotate(CitationsTitle, (.7,.06), weight='bold', fontsize=10, color='white')
plt.annotate(CitationsDesc, (.71,.04), weight='regular', fontsize=10, color='white')

plt.annotate(Footer, (.01,.01), weight='regular', fontsize=8, alpha=.75)

plt.savefig('EM_resume.pdf', dpi=300, bbox_inches='tight')

files.download('EM_resume.pdf')

# %% [markdown]
# source:
# https://towardsdatascience.com/generating-a-resume-in-python-1480a4d6a399
